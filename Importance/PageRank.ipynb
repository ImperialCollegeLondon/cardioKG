# %%
from neo4j import GraphDatabase
uri = "bolt://localhost:7687"
user = "neo4j"
password= "************"

gds = GraphDataScience(uri, auth=(user, password))

graph = Graph(uri, auth=(user, password))
driver = GraphDatabase.driver(uri, auth=("neo4j", "************"))

# %%
def CMR_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:CMR)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

CMR_pagerank_scores_df = CMR_get_pagerank_scores()

# %%
#Anatomy
def Anatomy_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:Anatomy)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

Anatomy_pagerank_scores_df = Anatomy_get_pagerank_scores()

# %%
#Gene
def Gene_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:Gene)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

Gene_pagerank_scores_df = Gene_get_pagerank_scores()

# %%
#Disease
def Disease_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:Disease)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

Disease_pagerank_scores_df = Disease_get_pagerank_scores()

# %%
#Medication
def Medication_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:Medication)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

Medication_pagerank_scores_df = Medication_get_pagerank_scores()

# %%
#BP
def BP_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:BP)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

BP_pagerank_scores_df = BP_get_pagerank_scores()

# %%
#CC
def CC_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:CC)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

CC_pagerank_scores_df = CC_get_pagerank_scores()

# %%
#MF
def MF_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:MF)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

MF_pagerank_scores_df = MF_get_pagerank_scores()

# %%
#Pathway
def Pathway_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:Pathway)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

Pathway_pagerank_scores_df = Pathway_get_pagerank_scores()

# %%
#Exposure
def Exposure_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:Exposure)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

Exposure_pagerank_scores_df = Exposure_get_pagerank_scores()

# %%
#Phenotype
def Phenotype_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:Phenotype)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

Phenotype_pagerank_scores_df = Phenotype_get_pagerank_scores()

# %%
#Patient
def Patient_get_pagerank_scores():
    with driver.session() as session:
        query = """
        CALL gds.pageRank.stream('myGraph2')
        YIELD nodeId, score
        WITH nodeId, score
        MATCH (n:Patient)
        WHERE id(n) = nodeId
        RETURN n.name AS node, score
        ORDER BY score DESC;
        """
        result = session.run(query)
        return pd.DataFrame(result.data())

Patient_pagerank_scores_df = Patient_get_pagerank_scores()
